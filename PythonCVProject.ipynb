# %%
### Data Analytics for 50km races

# %%
# Import Modules

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Get Data From CSV File

df = pd.read_csv(r"C:\Users\Artem\Desktop\Pandas\TWO_CENTURIES_OF_UM_RACES.csv")
df.head(100)
# Out:
# C:\Users\Artem\AppData\Local\Temp\ipykernel_18880\2674204130.py:3: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r"C:\Users\Artem\Desktop\Pandas\TWO_CENTURIES_OF_UM_RACES.csv")
#     Year of event Event dates                                   Event name  \
# 0            2018  06.01.2018                          Selva Costera (CHI)
# 1            2018  06.01.2018                          Selva Costera (CHI)
# 2            2018  06.01.2018                          Selva Costera (CHI)
# 3            2018  06.01.2018                          Selva Costera (CHI)
# 4            2018  06.01.2018                          Selva Costera (CHI)
# ..            ...         ...                                          ...
# 95           2018  06.01.2018  Yankee Springs 50 km Winter Challenge (USA)
# 96           2018  06.01.2018  Yankee Springs 50 km Winter Challenge (USA)
# 97           2018  06.01.2018  Yankee Springs 50 km Winter Challenge (USA)
# 98           2018  06.01.2018  Yankee Springs 50 km Winter Challenge (USA)
# 99           2018  06.01.2018  Yankee Springs 50 km Winter Challenge (USA)
#
#    Event distance/length  Event number of finishers Athlete performance  \
# 0                   50km                         22           4:51:39 h
# 1                   50km                         22           5:15:45 h
# 2                   50km                         22           5:16:44 h
# 3                   50km                         22           5:34:13 h
# 4                   50km                         22           5:54:14 h
# ..                   ...                        ...                 ...
# 95                  50km                         36           9:06:32 h
# 96                  50km                         36           9:19:01 h
# 97                  50km                         36          10:46:12 h
# 98                  50km                         36          10:46:28 h
# 99                  50km                         36          10:46:29 h
#
#           Athlete club Athlete country  Athlete year of birth Athlete gender  \
# 0                Tnfrc             CHI                 1978.0              M
# 1   Roberto Echeverría             CHI                 1981.0              M
# 2    Puro Trail Osorno             CHI                 1987.0              M
# 3             Columbia             ARG                 1976.0              M
# 4       Baguales Trail             CHI                 1992.0              M
# ..                 ...             ...                    ...            ...
# 95        *Portage, MI             USA                 1967.0              M
# 96       *Mattawan, MI             USA                 1972.0              F
# 97     *Farmington, MI             USA                 1987.0              F
# 98         *Coloma, MI             USA                 1978.0              M
# 99        *Jenison, MI             USA                 1977.0              F
#
#    Athlete age category Athlete average speed  Athlete ID
# 0                   M35                10.286           0
# 1                   M35                 9.501           1
# 2                   M23                 9.472           2
# 3                   M40                 8.976           3
# 4                   M23                 8.469           4
# ..                  ...                   ...         ...
# 95                  M50                 5.489          95
# 96                  W45                 5.367          96
# 97                  W23                 4.643          97
# 98                  M35                 4.641          98
# 99                  W40                  4.64          99
#
# [100 rows x 13 columns]

# %%
# Get Number of Columns/Rows for Table 

df.shape
# Out:
# (7461195, 13)

# %%
# look at Data Types in Table

df.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete club                  object
# Athlete country               object
# Athlete year of birth        float64
# Athlete gender                object
# Athlete age category          object
# Athlete average speed         object
# Athlete ID                     int64
# dtype: object

# %%
##  Data Cleaning Process

# %%
# Get Data Only for 50km Races

df2 = df[df['Event distance/length'].isin(['50km'])]
df2.head(10)
# Out:
#    Year of event Event dates           Event name Event distance/length  \
# 0           2018  06.01.2018  Selva Costera (CHI)                  50km
# 1           2018  06.01.2018  Selva Costera (CHI)                  50km
# 2           2018  06.01.2018  Selva Costera (CHI)                  50km
# 3           2018  06.01.2018  Selva Costera (CHI)                  50km
# 4           2018  06.01.2018  Selva Costera (CHI)                  50km
# 5           2018  06.01.2018  Selva Costera (CHI)                  50km
# 6           2018  06.01.2018  Selva Costera (CHI)                  50km
# 7           2018  06.01.2018  Selva Costera (CHI)                  50km
# 8           2018  06.01.2018  Selva Costera (CHI)                  50km
# 9           2018  06.01.2018  Selva Costera (CHI)                  50km
#
#    Event number of finishers Athlete performance         Athlete club  \
# 0                         22           4:51:39 h                Tnfrc
# 1                         22           5:15:45 h   Roberto Echeverría
# 2                         22           5:16:44 h    Puro Trail Osorno
# 3                         22           5:34:13 h             Columbia
# 4                         22           5:54:14 h       Baguales Trail
# 5                         22           6:25:01 h                  NaN
# 6                         22           6:28:00 h        Los Patagones
# 7                         22           6:32:24 h       Reaktiva Chile
# 8                         22           6:39:08 h    Puro Trail Osorno
# 9                         22           6:45:11 h  Marlene Flores Team
#
#   Athlete country  Athlete year of birth Athlete gender Athlete age category  \
# 0             CHI                 1978.0              M                  M35
# 1             CHI                 1981.0              M                  M35
# 2             CHI                 1987.0              M                  M23
# 3             ARG                 1976.0              M                  M40
# 4             CHI                 1992.0              M                  M23
# 5             ARG                 1974.0              M                  M40
# 6             ARG                 1979.0              F                  W35
# 7             CHI                 1967.0              F                  W50
# 8             CHI                 1985.0              M                  M23
# 9             CHI                 1976.0              M                  M40
#
#   Athlete average speed  Athlete ID
# 0                10.286           0
# 1                 9.501           1
# 2                 9.472           2
# 3                 8.976           3
# 4                 8.469           4
# 5                 7.792           5
# 6                 7.732           6
# 7                 7.645           7
# 8                 7.516           8
# 9                 7.404           9

# %%
# Split 'Event name' Column to Get Only Countries

df2['Event name'] = df2['Event name'].str.split('(').str.get(1).str.split(')').str.get(0)
df2.head(10)
# Out:
# C:\Users\Artem\AppData\Local\Temp\ipykernel_18880\2151140244.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Event name'] = df2['Event name'].str.split('(').str.get(1).str.split(')').str.get(0)
#    Year of event Event dates Event name Event distance/length  \
# 0           2018  06.01.2018        CHI                  50km
# 1           2018  06.01.2018        CHI                  50km
# 2           2018  06.01.2018        CHI                  50km
# 3           2018  06.01.2018        CHI                  50km
# 4           2018  06.01.2018        CHI                  50km
# 5           2018  06.01.2018        CHI                  50km
# 6           2018  06.01.2018        CHI                  50km
# 7           2018  06.01.2018        CHI                  50km
# 8           2018  06.01.2018        CHI                  50km
# 9           2018  06.01.2018        CHI                  50km
#
#    Event number of finishers Athlete performance         Athlete club  \
# 0                         22           4:51:39 h                Tnfrc
# 1                         22           5:15:45 h   Roberto Echeverría
# 2                         22           5:16:44 h    Puro Trail Osorno
# 3                         22           5:34:13 h             Columbia
# 4                         22           5:54:14 h       Baguales Trail
# 5                         22           6:25:01 h                  NaN
# 6                         22           6:28:00 h        Los Patagones
# 7                         22           6:32:24 h       Reaktiva Chile
# 8                         22           6:39:08 h    Puro Trail Osorno
# 9                         22           6:45:11 h  Marlene Flores Team
#
#   Athlete country  Athlete year of birth Athlete gender Athlete age category  \
# 0             CHI                 1978.0              M                  M35
# 1             CHI                 1981.0              M                  M35
# 2             CHI                 1987.0              M                  M23
# 3             ARG                 1976.0              M                  M40
# 4             CHI                 1992.0              M                  M23
# 5             ARG                 1974.0              M                  M40
# 6             ARG                 1979.0              F                  W35
# 7             CHI                 1967.0              F                  W50
# 8             CHI                 1985.0              M                  M23
# 9             CHI                 1976.0              M                  M40
#
#   Athlete average speed  Athlete ID
# 0                10.286           0
# 1                 9.501           1
# 2                 9.472           2
# 3                 8.976           3
# 4                 8.469           4
# 5                 7.792           5
# 6                 7.732           6
# 7                 7.645           7
# 8                 7.516           8
# 9                 7.404           9

# %%
# Get Exact Athlete Age

df2['Athlete Age'] = df2['Year of event'] - df2['Athlete year of birth']
df2.head(10)
# Out:
# C:\Users\Artem\AppData\Local\Temp\ipykernel_18880\2638828566.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Athlete Age'] = df2['Year of event'] - df2['Athlete year of birth']
#    Year of event Event dates Event name Event distance/length  \
# 0           2018  06.01.2018        CHI                  50km
# 1           2018  06.01.2018        CHI                  50km
# 2           2018  06.01.2018        CHI                  50km
# 3           2018  06.01.2018        CHI                  50km
# 4           2018  06.01.2018        CHI                  50km
# 5           2018  06.01.2018        CHI                  50km
# 6           2018  06.01.2018        CHI                  50km
# 7           2018  06.01.2018        CHI                  50km
# 8           2018  06.01.2018        CHI                  50km
# 9           2018  06.01.2018        CHI                  50km
#
#    Event number of finishers Athlete performance         Athlete club  \
# 0                         22           4:51:39 h                Tnfrc
# 1                         22           5:15:45 h   Roberto Echeverría
# 2                         22           5:16:44 h    Puro Trail Osorno
# 3                         22           5:34:13 h             Columbia
# 4                         22           5:54:14 h       Baguales Trail
# 5                         22           6:25:01 h                  NaN
# 6                         22           6:28:00 h        Los Patagones
# 7                         22           6:32:24 h       Reaktiva Chile
# 8                         22           6:39:08 h    Puro Trail Osorno
# 9                         22           6:45:11 h  Marlene Flores Team
#
#   Athlete country  Athlete year of birth Athlete gender Athlete age category  \
# 0             CHI                 1978.0              M                  M35
# 1             CHI                 1981.0              M                  M35
# 2             CHI                 1987.0              M                  M23
# 3             ARG                 1976.0              M                  M40
# 4             CHI                 1992.0              M                  M23
# 5             ARG                 1974.0              M                  M40
# 6             ARG                 1979.0              F                  W35
# 7             CHI                 1967.0              F                  W50
# 8             CHI                 1985.0              M                  M23
# 9             CHI                 1976.0              M                  M40
#
#   Athlete average speed  Athlete ID  Athlete Age
# 0                10.286           0         40.0
# 1                 9.501           1         37.0
# 2                 9.472           2         31.0
# 3                 8.976           3         42.0
# 4                 8.469           4         26.0
# 5                 7.792           5         44.0
# 6                 7.732           6         39.0
# 7                 7.645           7         51.0
# 8                 7.516           8         33.0
# 9                 7.404           9         42.0

# %%
# Remove 'h' from 'Athlete performance' column values

df2['Athlete performance'] = df2['Athlete performance'].str.split(' ').str.get(0)
df2.head(10)
# Out:
# C:\Users\Artem\AppData\Local\Temp\ipykernel_18880\1087723880.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Athlete performance'] = df2['Athlete performance'].str.split(' ').str.get(0)
#    Year of event Event dates Event name Event distance/length  \
# 0           2018  06.01.2018        CHI                  50km
# 1           2018  06.01.2018        CHI                  50km
# 2           2018  06.01.2018        CHI                  50km
# 3           2018  06.01.2018        CHI                  50km
# 4           2018  06.01.2018        CHI                  50km
# 5           2018  06.01.2018        CHI                  50km
# 6           2018  06.01.2018        CHI                  50km
# 7           2018  06.01.2018        CHI                  50km
# 8           2018  06.01.2018        CHI                  50km
# 9           2018  06.01.2018        CHI                  50km
#
#    Event number of finishers Athlete performance         Athlete club  \
# 0                         22             4:51:39                Tnfrc
# 1                         22             5:15:45   Roberto Echeverría
# 2                         22             5:16:44    Puro Trail Osorno
# 3                         22             5:34:13             Columbia
# 4                         22             5:54:14       Baguales Trail
# 5                         22             6:25:01                  NaN
# 6                         22             6:28:00        Los Patagones
# 7                         22             6:32:24       Reaktiva Chile
# 8                         22             6:39:08    Puro Trail Osorno
# 9                         22             6:45:11  Marlene Flores Team
#
#   Athlete country  Athlete year of birth Athlete gender Athlete age category  \
# 0             CHI                 1978.0              M                  M35
# 1             CHI                 1981.0              M                  M35
# 2             CHI                 1987.0              M                  M23
# 3             ARG                 1976.0              M                  M40
# 4             CHI                 1992.0              M                  M23
# 5             ARG                 1974.0              M                  M40
# 6             ARG                 1979.0              F                  W35
# 7             CHI                 1967.0              F                  W50
# 8             CHI                 1985.0              M                  M23
# 9             CHI                 1976.0              M                  M40
#
#   Athlete average speed  Athlete ID  Athlete Age
# 0                10.286           0         40.0
# 1                 9.501           1         37.0
# 2                 9.472           2         31.0
# 3                 8.976           3         42.0
# 4                 8.469           4         26.0
# 5                 7.792           5         44.0
# 6                 7.732           6         39.0
# 7                 7.645           7         51.0
# 8                 7.516           8         33.0
# 9                 7.404           9         42.0

# %%
# Remove Needless Columns

df3 = df2.drop(['Event number of finishers','Athlete club','Athlete year of birth','Athlete age category'], axis = 1)
df3.head(10)
# Out:
#    Year of event Event dates Event name Event distance/length  \
# 0           2018  06.01.2018        CHI                  50km
# 1           2018  06.01.2018        CHI                  50km
# 2           2018  06.01.2018        CHI                  50km
# 3           2018  06.01.2018        CHI                  50km
# 4           2018  06.01.2018        CHI                  50km
# 5           2018  06.01.2018        CHI                  50km
# 6           2018  06.01.2018        CHI                  50km
# 7           2018  06.01.2018        CHI                  50km
# 8           2018  06.01.2018        CHI                  50km
# 9           2018  06.01.2018        CHI                  50km
#
#   Athlete performance Athlete country Athlete gender Athlete average speed  \
# 0             4:51:39             CHI              M                10.286
# 1             5:15:45             CHI              M                 9.501
# 2             5:16:44             CHI              M                 9.472
# 3             5:34:13             ARG              M                 8.976
# 4             5:54:14             CHI              M                 8.469
# 5             6:25:01             ARG              M                 7.792
# 6             6:28:00             ARG              F                 7.732
# 7             6:32:24             CHI              F                 7.645
# 8             6:39:08             CHI              M                 7.516
# 9             6:45:11             CHI              M                 7.404
#
#    Athlete ID  Athlete Age
# 0           0         40.0
# 1           1         37.0
# 2           2         31.0
# 3           3         42.0
# 4           4         26.0
# 5           5         44.0
# 6           6         39.0
# 7           7         51.0
# 8           8         33.0
# 9           9         42.0

# %%
# Search for Null Values

df3.isnull().sum()
# Out:
# Year of event                 0
# Event dates                   0
# Event name                    0
# Event distance/length         0
# Athlete performance           1
# Athlete country               2
# Athlete gender                1
# Athlete average speed         1
# Athlete ID                    0
# Athlete Age              123783
# dtype: int64

# %%
# Dispay Null Value

df3[df3['Athlete Age'].isna() == 1]
# Out:
#          Year of event Event dates Event name Event distance/length  \
# 11                2018  06.01.2018        CHI                  50km
# 19                2018  06.01.2018        CHI                  50km
# 20                2018  06.01.2018        CHI                  50km
# 246               2018  02.01.2018        AUS                  50km
# 247               2018  02.01.2018        AUS                  50km
# ...                ...         ...        ...                   ...
# 7461021           1995  21.01.1995        USA                  50km
# 7461023           1995  21.01.1995        USA                  50km
# 7461079           1995  07.01.1995        AUS                  50km
# 7461081           1995  07.01.1995        AUS                  50km
# 7461086           1995  07.01.1995        AUS                  50km
#
#         Athlete performance Athlete country Athlete gender  \
# 11                  7:09:58             CHI              M
# 19                  8:13:16             CHI              M
# 20                  8:13:28             CHI              M
# 246                 4:59:11             AUS              M
# 247                 5:03:10             AUS              M
# ...                     ...             ...            ...
# 7461021             6:00:12             USA              M
# 7461023             7:08:08             USA              M
# 7461079             5:40:24             AUS              M
# 7461081             5:42:46             AUS              M
# 7461086             5:49:58             AUS              F
#
#         Athlete average speed  Athlete ID  Athlete Age
# 11                      6.977          11          NaN
# 19                      6.082          19          NaN
# 20                      6.079          20          NaN
# 246                    10.027         246          NaN
# 247                     9.896         247          NaN
# ...                       ...         ...          ...
# 7461021                8329.0     1641162          NaN
# 7461023                7007.0     1641163          NaN
# 7461079                8813.0     1641166          NaN
# 7461081                8752.0     1093063          NaN
# 7461086                8572.0     1641111          NaN
#
# [123783 rows x 10 columns]

# %%
# Remove Data With Null Values

df3 = df3.dropna()

# %%
# Search For Duplicates

df3[df3.duplicated() == True]
# Out:
#          Year of event Event dates Event name Event distance/length  \
# 150701            2018  08.04.2018        GER                  50km
# 150702            2018  08.04.2018        GER                  50km
# 150703            2018  08.04.2018        GER                  50km
# 150704            2018  08.04.2018        GER                  50km
# 150705            2018  08.04.2018        GER                  50km
# ...                ...         ...        ...                   ...
# 6709655           2015  29.08.2015        USA                  50km
# 6709656           2015  29.08.2015        USA                  50km
# 6709657           2015  29.08.2015        USA                  50km
# 6812728           2015  11.10.2015        TPE                  50km
# 7245772           1990  28.04.1990        GER                  50km
#
#         Athlete performance Athlete country Athlete gender  \
# 150701              3:03:27             GER              M
# 150702              3:07:20             GER              M
# 150703              3:11:25             GER              M
# 150704              3:13:21             GER              M
# 150705              3:15:23             GER              M
# ...                     ...             ...            ...
# 6709655             7:44:04             USA              M
# 6709656             7:58:20             USA              F
# 6709657             9:07:24             USA              F
# 6812728            12:50:00             HKG              M
# 7245772             3:33:14             GER              F
#
#         Athlete average speed  Athlete ID  Athlete Age
# 150701                 16.353        5228         35.0
# 150702                 16.014      119919         28.0
# 150703                 15.673      119920         37.0
# 150704                 15.516      119921         38.0
# 150705                 15.354      119922         35.0
# ...                       ...         ...          ...
# 6709655                 6.465      133326         48.0
# 6709656                 6.272     1507620         33.0
# 6709657                  5.48     1507621         29.0
# 6812728                 3.896       35836         45.0
# 7245772               14069.0     1047147         25.0
#
# [2659 rows x 10 columns]

# %%
# Remove Duplicates

df3 = df3.drop_duplicates()

# %%
# Reset Indexes

df3.reset_index(drop = True)
# Out:
#          Year of event Event dates Event name Event distance/length  \
# 0                 2018  06.01.2018        CHI                  50km
# 1                 2018  06.01.2018        CHI                  50km
# 2                 2018  06.01.2018        CHI                  50km
# 3                 2018  06.01.2018        CHI                  50km
# 4                 2018  06.01.2018        CHI                  50km
# ...                ...         ...        ...                   ...
# 1396162           1995  07.01.1995        AUS                  50km
# 1396163           1995  07.01.1995        AUS                  50km
# 1396164           1995  07.01.1995        AUS                  50km
# 1396165           1995  07.01.1995        AUS                  50km
# 1396166           1995  07.01.1995        AUS                  50km
#
#         Athlete performance Athlete country Athlete gender  \
# 0                   4:51:39             CHI              M
# 1                   5:15:45             CHI              M
# 2                   5:16:44             CHI              M
# 3                   5:34:13             ARG              M
# 4                   5:54:14             CHI              M
# ...                     ...             ...            ...
# 1396162             4:19:56             AUS              F
# 1396163             4:28:57             AUS              M
# 1396164             4:46:39             AUS              M
# 1396165             4:47:39             AUS              M
# 1396166             5:58:16             AUS              F
#
#         Athlete average speed  Athlete ID  Athlete Age
# 0                      10.286           0         40.0
# 1                       9.501           1         37.0
# 2                       9.472           2         31.0
# 3                       8.976           3         42.0
# 4                       8.469           4         26.0
# ...                       ...         ...          ...
# 1396162               11541.0     1046326         39.0
# 1396163               11154.0     1070007         41.0
# 1396164               10466.0      345672         44.0
# 1396165               10429.0     1082443         56.0
# 1396166                8374.0     1082581         57.0
#
# [1396167 rows x 10 columns]

# %%
# Fixing Data Types 

df3.dtypes
# Out:
# Year of event              int64
# Event dates               object
# Event name                object
# Event distance/length     object
# Athlete performance       object
# Athlete country           object
# Athlete gender            object
# Athlete average speed     object
# Athlete ID                 int64
# Athlete Age              float64
# dtype: object

# %%
# Changing Data type for 'Athlete Age' to integer

df3['Athlete Age'] = df3['Athlete Age'].astype(int)

# %%
# Find Bad Data Values in 'Athlete average speed' column

df3[df3['Athlete average speed'].str.contains(':') == True]
# Out:
#          Year of event Event dates Event name Event distance/length  \
# 2078465           2019  04.05.2019        USA                  50km
# 2078466           2019  04.05.2019        USA                  50km
# 2078467           2019  04.05.2019        USA                  50km
# 2078468           2019  04.05.2019        USA                  50km
# 2078469           2019  04.05.2019        USA                  50km
# ...                ...         ...        ...                   ...
# 3451841           2022  30.07.2022        GER                  50km
# 3451842           2022  30.07.2022        GER                  50km
# 3451843           2022  30.07.2022        GER                  50km
# 3451844           2022  30.07.2022        GER                  50km
# 3451845           2022  30.07.2022        GER                  50km
#
#         Athlete performance Athlete country Athlete gender  \
# 2078465             3:44:54             USA              M
# 2078466             4:37:03             USA              M
# 2078467             4:40:03             USA              M
# 2078468             4:48:08             USA              M
# 2078469             4:48:16             USA              M
# ...                     ...             ...            ...
# 3451841             7:36:00             GER              M
# 3451842             7:41:00             GER              F
# 3451843             7:44:00             GER              F
# 3451844             7:56:00             GER              M
# 3451845             8:31:00             GER              F
#
#         Athlete average speed  Athlete ID  Athlete Age
# 2078465              03:44:54      528765           41
# 2078466              04:37:03      706557           42
# 2078467              04:40:03      577559           32
# 2078468              04:48:08      656702           31
# 2078469              04:48:16      706558           30
# ...                       ...         ...          ...
# 3451841              07:36:00       59120           51
# 3451842              07:41:00     1010392           29
# 3451843              07:44:00      685130           43
# 3451844              07:56:00     1010393           31
# 3451845              08:31:00      696119           36
#
# [78 rows x 10 columns]

# %%
# Remove Values with Bad Data Format

df3 = df3.drop(df3[df3['Athlete average speed'].str.contains(':') == True].index)

# %%
# Changing Data type for 'Athlete average speed' to float

df3['Athlete average speed'] = df3['Athlete average speed'].astype(float)

# %%
df3.head()
# Out:
#    Year of event Event dates Event name Event distance/length  \
# 0           2018  06.01.2018        CHI                  50km
# 1           2018  06.01.2018        CHI                  50km
# 2           2018  06.01.2018        CHI                  50km
# 3           2018  06.01.2018        CHI                  50km
# 4           2018  06.01.2018        CHI                  50km
#
#   Athlete performance Athlete country Athlete gender  Athlete average speed  \
# 0             4:51:39             CHI              M                 10.286
# 1             5:15:45             CHI              M                  9.501
# 2             5:16:44             CHI              M                  9.472
# 3             5:34:13             ARG              M                  8.976
# 4             5:54:14             CHI              M                  8.469
#
#    Athlete ID  Athlete Age
# 0           0           40
# 1           1           37
# 2           2           31
# 3           3           42
# 4           4           26

# %%
# Rename Columns For Easiest Access

df3 = df3.rename(columns = {'Year of event': 'year',
                            'Event dates': 'race_date',
                            'Event name': 'event_country',
                            'Event distance/length': 'lengh',
                            'Athlete performance': 'runner_time',
                            'Athlete country': 'runner_country',
                            'Athlete gender': 'gender',
                            'Athlete average speed': 'average_speed',
                            'Athlete ID': 'runnerId',
                            'Athlete Age': 'age' })

# %%
df3.head()
# Out:
#    year   race_date event_country lengh runner_time runner_country gender  \
# 0  2018  06.01.2018           CHI  50km     4:51:39            CHI      M
# 1  2018  06.01.2018           CHI  50km     5:15:45            CHI      M
# 2  2018  06.01.2018           CHI  50km     5:16:44            CHI      M
# 3  2018  06.01.2018           CHI  50km     5:34:13            ARG      M
# 4  2018  06.01.2018           CHI  50km     5:54:14            CHI      M
#
#    average_speed  runnerId  age
# 0         10.286         0   40
# 1          9.501         1   37
# 2          9.472         2   31
# 3          8.976         3   42
# 4          8.469         4   26

# %%
# Reorder Columns

df4 = df3[['year','race_date','event_country','lengh','runner_country','runner_time','average_speed','gender','age','runnerId']]

# %%
df4.head()
# Out:
#    year   race_date event_country lengh runner_country runner_time  \
# 0  2018  06.01.2018           CHI  50km            CHI     4:51:39
# 1  2018  06.01.2018           CHI  50km            CHI     5:15:45
# 2  2018  06.01.2018           CHI  50km            CHI     5:16:44
# 3  2018  06.01.2018           CHI  50km            ARG     5:34:13
# 4  2018  06.01.2018           CHI  50km            CHI     5:54:14
#
#    average_speed gender  age  runnerId
# 0         10.286      M   40         0
# 1          9.501      M   37         1
# 2          9.472      M   31         2
# 3          8.976      M   42         3
# 4          8.469      M   26         4

# %%
# Remove Extra Value 'x' in gender column

df4 = df4.drop(df4[df4['gender'].str.contains('X') == True].index)

# %%
## Creating Additional Columns For Analysis

# %%
# Create Separate Column for Months

df4['race_month'] = df4['race_date'].str.split('.').str.get(1).astype(int)

# %%
# Create Separate Column For Season

df4['race_season'] = df4['race_month'].apply(lambda x: 'Winter' if x > 11 else 'Fall' if x > 8 else 'Summer' if x > 5 else 'Spring' if x > 2 else 'Winter' )

# %%
# Take Only Correct Speed Values From 'average_speed'

df4 = df4[df4['average_speed'] < 20]

# %%
# Take Only Runners > 18 years old

df4 = df4[df4['age'] > 17]

# %%
# Take Runners under 99

df4 = df4[df4['age'] < 100]

# %%
df4.head()
# Out:
#    year   race_date event_country lengh runner_country runner_time  \
# 0  2018  06.01.2018           CHI  50km            CHI     4:51:39
# 1  2018  06.01.2018           CHI  50km            CHI     5:15:45
# 2  2018  06.01.2018           CHI  50km            CHI     5:16:44
# 3  2018  06.01.2018           CHI  50km            ARG     5:34:13
# 4  2018  06.01.2018           CHI  50km            CHI     5:54:14
#
#    average_speed gender  age  runnerId  race_month race_season
# 0         10.286      M   40         0           1      Winter
# 1          9.501      M   37         1           1      Winter
# 2          9.472      M   31         2           1      Winter
# 3          8.976      M   42         3           1      Winter
# 4          8.469      M   26         4           1      Winter

# %%
## Analyze Data

# %%
# Find Runners Average Age by Genders + Amount of Runners by Gender

df4.groupby(['gender'])['age'].agg(['mean','count']).round(2)
# Out:
#          mean    count
# gender
# F       41.10   367516
# M       42.59  1001551

# %%
# Amount Of Runners Difference By Genders

sns.displot(data = df4, x ='gender', hue = 'gender')
# Out:
# D:\Python\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# Runners Ages

sns.set(rc={'figure.figsize':(19,10)})

sns.countplot(df4, x="age", hue = 'gender')
# Out:
# <Axes: xlabel='age', ylabel='count'>

# %%
# Find Average Speed by Gender

df4.groupby(['gender'])['average_speed'].mean().round(2)
# Out:
# gender
# F    7.36
# M    8.12
# Name: average_speed, dtype: float64

# %%
# Runners Speed By Gender

sns.displot(data=df4, x="average_speed", hue="gender", kind="kde")
# Out:
# D:\Python\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# Find Average Speed by Age 

df4.groupby(['age'])['average_speed'].mean().round(2)
# Out:
# age
# 18    7.89
# 19    8.07
# 20    8.32
# 21    8.38
# 22    8.31
#       ...
# 93    4.76
# 94    4.46
# 95    5.70
# 98    7.13
# 99    6.70
# Name: average_speed, Length: 79, dtype: float64

# %%
# Top 3 Fastest Runners by Age 

df4.groupby(['age'])['average_speed'].agg(['mean']).sort_values('mean', ascending = False).head(3).round(2)
# Out:
#      mean
# age
# 21   8.38
# 20   8.32
# 22   8.31

# %%
# Top 3 Slowest Runners by Age 

df4.groupby(['age'])['average_speed'].agg(['mean']).sort_values('mean', ascending = True).head(3).round(2)
# Out:
#      mean
# age
# 94   4.46
# 93   4.76
# 91   5.03

# %%
# Amount of Runners by Years

df4.groupby(['year'])['runnerId'].count()
# Out:
# year
# 1996      8811
# 1997     10419
# 1998     11590
# 1999     14190
# 2000     19164
# 2001     16804
# 2002     18509
# 2003     20710
# 2004     22942
# 2005     22362
# 2006     24394
# 2007     32039
# 2008     33409
# 2009     42030
# 2010     58281
# 2011     63453
# 2012     84091
# 2013     93405
# 2014    103562
# 2015    114790
# 2016    130303
# 2017    147822
# 2018    154129
# 2019    174852
# 2020     59880
# 2021     90755
# 2022    100707
# Name: runnerId, dtype: int64

# %%
# Amount of Runners By Years Plot

sns.set(rc={'figure.figsize':(13,7)})

sns.countplot(df4, x="year")
# Out:
# <Axes: xlabel='year', ylabel='count'>

# %%
# Amount Of Runners by Country 

df4.groupby(['runner_country'])['runner_country'].count().sort_values(ascending = False)
# Out:
# runner_country
# USA    604814
# RSA    146124
# CHN     74767
# FRA     63871
# GER     55452
#         ...
# MTN         1
# FRO         1
# FIJ         1
# BAR         1
# NFI         1
# Name: runner_country, Length: 169, dtype: int64

# %%
# Average Speed by Seasons

df4.groupby(['race_season'])['average_speed'].agg(['mean','count']).sort_values('mean', ascending = False)
# Out:
#                  mean   count
# race_season
# Spring       8.229849  607696
# Winter       7.721714  337527
# Fall         7.615708  434878
# Summer       7.454338  293302

# %%
### Conclusions

# Average Age of Runners - 42.19 years
# Most Of Runners in Races was Mens
# Mens Average Speed was a Little Faster than Womens - 8.12 km/hour VS 7.36 km/hour
# Fastest Age Of Runners was - 21 Years - 8.38 km/hour
# Slowest Age of Runners was - 94 Years - 4.46 km/hour
# Year with Most Runners was - 2019 
# Country From Where Most Runners - USA(604814)
# Best Season for Races was Spring - With Best Average Speed Performance - 8.34 km/hour
